# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ../scripts
# Out:
# /Users/kadofong/work/merian/skipper/scripts

# %%
import make_pointings

# %%
cosmos = make_pointings.build_cosmos ()
gama = make_pointings.build_gama ()

# %%
mastercat, is_queued = make_pointings.predict_s2021a ()
# Out:
# 2021-03-18 04:00:00
# Deprioritizing N=13 targets
# 2021/03/05 09:00 PM
# 2021/03/06 01:57 AM
# 2021-03-06 04:00:00
# ==> 20210306_00, 3600.000000000005s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# [to_json] Inserting 60s focus exposures
# ==> 20210306_01, 3600.0s available
# 3600.0s filled by priority=0.0 objects
# 0.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# [to_json] Inserting 60s focus exposures
# ==> 20210306_02, 3600.0s available
# 3600.0s filled by priority=0.0 objects
# 0.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# [to_json] Inserting 60s focus exposures
# ==> 20210306_03, 3600.0s available
# 3600.0s filled by priority=0.0 objects
# 0.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# [to_json] Inserting 60s focus exposures
# (180s) Not enough time for an exposure. Skipping...
# 2021/03/06 08:54 PM
# 2021/03/07 01:54 AM
# 2021-03-07 04:00:00
# (360s) Not enough time for an exposure. Skipping...
# ==> 20210307_00, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210307_01, 3600.0s available
# 3600.0s filled by priority=0.0 objects
# 0.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210307_02, 3600.0s available
# 3600.0s filled by priority=0.0 objects
# 0.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210307_03, 3600.0s available
# 3600.0s filled by priority=0.0 objects
# 0.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# (360s) Not enough time for an exposure. Skipping...
# 2021/03/07 08:54 PM
# 2021/03/08 01:54 AM
# 2021-03-08 04:00:00
# (360s) Not enough time for an exposure. Skipping...
# ==> 20210308_00, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210308_01, 3600.0s available
# 2400.0s filled by priority=0.0 objects
# 1200.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210308_02, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210308_03, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# (360s) Not enough time for an exposure. Skipping...
# 2021/03/08 08:54 PM
# 2021/03/09 01:54 AM
# 2021-03-09 04:00:00
# (360s) Not enough time for an exposure. Skipping...
# ==> 20210309_00, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210309_01, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210309_02, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210309_03, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# (360s) Not enough time for an exposure. Skipping...
# 2021/03/09 08:54 PM
# 2021/03/10 01:54 AM
# 2021-03-10 04:00:00
# (360s) Not enough time for an exposure. Skipping...
# ==> 20210310_00, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210310_01, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210310_02, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210310_03, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# (360s) Not enough time for an exposure. Skipping...
# 2021/03/10 08:54 PM
# 2021/03/11 01:54 AM
# 2021-03-11 04:00:00
# (360s) Not enough time for an exposure. Skipping...
# ==> 20210311_00, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210311_01, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210311_02, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210311_03, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# (360s) Not enough time for an exposure. Skipping...
# 2021/03/11 08:48 PM
# 2021/03/12 01:51 AM
# 2021-03-12 04:00:00
# ==> 20210311_23, 719.9999999999911s available
# 0.0s filled by priority=0.0 objects
# 0.0s filled by priority=1.0 objects
# 600.0s filled by priority=2.0 objects
# ==> 20210312_00, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210312_01, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210312_02, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210312_03, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# (540s) Not enough time for an exposure. Skipping...
# 2021/03/13 08:48 PM
# 2021/03/14 01:54 AM
# 2021-03-14 04:00:00
# ==> 20210313_23, 719.9999999999911s available
# 0.0s filled by priority=0.0 objects
# 0.0s filled by priority=1.0 objects
# 600.0s filled by priority=2.0 objects
# ==> 20210314_00, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210314_01, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210314_02, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210314_03, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# (360s) Not enough time for an exposure. Skipping...
# 2021/03/14 08:48 PM
# 2021/03/15 01:54 AM
# 2021-03-15 04:00:00
# ==> 20210314_23, 719.9999999999911s available
# 0.0s filled by priority=0.0 objects
# 0.0s filled by priority=1.0 objects
# 600.0s filled by priority=2.0 objects
# ==> 20210315_00, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210315_01, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210315_02, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210315_03, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# (360s) Not enough time for an exposure. Skipping...
# 2021/03/15 08:48 PM
# 2021/03/16 01:54 AM
# 2021-03-16 04:00:00
# ==> 20210315_23, 719.9999999999911s available
# 0.0s filled by priority=0.0 objects
# 0.0s filled by priority=1.0 objects
# 600.0s filled by priority=2.0 objects
# ==> 20210316_00, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210316_01, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210316_02, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210316_03, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# (360s) Not enough time for an exposure. Skipping...
# 2021/03/16 08:42 PM
# 2021/03/17 01:51 AM
# 2021-03-17 04:00:00
# ==> 20210316_23, 1079.9999999999898s available
# 0.0s filled by priority=0.0 objects
# 0.0s filled by priority=1.0 objects
# 600.0s filled by priority=2.0 objects
# ==> 20210317_00, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 600.0s filled by priority=1.0 objects
# 3000.0s filled by priority=2.0 objects
# ==> 20210317_01, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210317_02, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210317_03, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# (540s) Not enough time for an exposure. Skipping...
# 2021/03/17 08:42 PM
# 2021/03/18 01:51 AM
# 2021-03-18 04:00:00
# ==> 20210317_23, 1079.9999999999898s available
# 0.0s filled by priority=0.0 objects
# 0.0s filled by priority=1.0 objects
# 600.0s filled by priority=2.0 objects
# ==> 20210318_00, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 0.0s filled by priority=1.0 objects
# 1200.0s filled by priority=2.0 objects
# !!! Cannot fill queue !!! 2400.0, 600.0
# /Users/kadofong/work/merian/skipper/python/skipper/observe.py:264: UserWarning: Queue unfilled at 20210318_00
#   warnings.warn(f'Queue unfilled at {hstr}')
# ==> 20210318_01, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210318_02, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# ==> 20210318_03, 3600.0s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# (540s) Not enough time for an exposure. Skipping...

# %%
mastercat.loc[is_queued.is_queued].to_csv('../pointings/S2021A_predicted.csv')

# %%
is_queued
# Out:
#      is_queued       qstamp  has_priority             airmass
# 0        False                        1.0                 NaN
# 1        False                        1.0                 NaN
# 2        False                        1.0                 NaN
# 3        False                        1.0                 NaN
# 4        False                        1.0                 NaN
# 5        False                        1.0                 NaN
# 6        False                        1.0                 NaN
# 7        False                        1.0                 NaN
# 8        False                        1.0                 NaN
# 9        False                        1.0                 NaN
# 10       False                        1.0                 NaN
# 11       False                        1.0                 NaN
# 12       False                        1.0                 NaN
# 13       False                        1.0                 NaN
# 14       False                        1.0                 NaN
# 15       False                        1.0                 NaN
# 16       False                        1.0                 NaN
# 17       False                        1.0                 NaN
# 18       False                        1.0                 NaN
# 19       False                        1.0                 NaN
# 20       False                        1.0                 NaN
# 21       False                        1.0                 NaN
# 22       False                        1.0                 NaN
# 23       False                        1.0                 NaN
# 24       False                        1.0                 NaN
# 25       False                        1.0                 NaN
# 26       False                        1.0                 NaN
# 27       False                        1.0                 NaN
# 28       False                        1.0                 NaN
# 29       False                        1.0                 NaN
# ..         ...          ...           ...                 ...
# 522       True  20210307_01           0.0  1.4283662725988457
# 523       True  20210308_01           0.0  1.4129105481858892
# 524       True  20210308_01           0.0  1.4130202511351593
# 525       True  20210307_03           0.0   1.185795849415476
# 526       True  20210306_03           0.0  1.1863798709453381
# 527       True  20210307_01           0.0  1.4280780651284462
# 528       True  20210308_01           0.0  1.4135326797445713
# 529       True  20210307_03           0.0  1.1857517235767543
# 530       True  20210307_02           0.0   1.250643789790987
# 531       True  20210307_01           0.0   1.427131582326476
# 532       True  20210306_01           0.0  1.4433443905519014
# 533       True  20210306_03           0.0   1.186309254481904
# 534       True  20210306_01           0.0  1.4429526454673671
# 535       True  20210306_02           0.0  1.2566912113997035
# 536       True  20210307_03           0.0   1.185707803296437
# 537       True  20210306_03           0.0   1.186105729293453
# 538       True  20210306_01           0.0  1.4438457751972094
# 539       True  20210306_01           0.0  1.4429189544260799
# 540       True  20210307_01           0.0  1.4273017230970595
# 541       True  20210307_02           0.0  1.2506175812347367
# 542       True  20210306_01           0.0   1.443959691225846
# 543       True  20210307_03           0.0  1.1858129388819862
# 544       True  20210306_03           0.0   1.186410019028875
# 545       True  20210306_02           0.0  1.2569971217739522
# 546       True  20210306_02           0.0  1.2565875112369227
# 547       True  20210306_03           0.0  1.1863694067701684
# 548       True  20210307_03           0.0  1.1855496244596595
# 549       True  20210307_02           0.0   1.250436173294149
# 550       True  20210308_01           0.0  1.4126771011993482
# 551       True  20210306_02           0.0   1.256905226763406
#
# [552 rows x 4 columns]
