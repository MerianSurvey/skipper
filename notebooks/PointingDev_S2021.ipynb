# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ../scripts
# Out:
# /Users/kadofong/work/merian/skipper/scripts

# %%
import numpy as np
import pandas as pd
import make_pointings

# %%
cosmos = make_pointings.build_cosmos ()
gama = make_pointings.build_gama ()

# %%
mastercat, is_queued = make_pointings.predict_s2021a ()
# Out:
# /Users/kadofong/work/merian/skipper/scripts/make_pointings.py:76: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   mastercat = pd.concat([gama,cosmos])
# 2021-03-18 04:00:00
# Deprioritizing N=13 targets
# 2021/03/05 09:00 PM
# 2021/03/06 01:57 AM
# 2021-03-06 04:00:00
# ==> 20210306_00, 3600.000000000005s available
# 0.0s filled by priority=0.0 objects
# 3600.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# [to_json] Inserting 60s focus exposures
# ==> 20210306_01, 3600.0s available
# 3600.0s filled by priority=0.0 objects
# 0.0s filled by priority=1.0 objects
# 0.0s filled by priority=2.0 objects
# [to_json] Inserting 60s focus exposures
# ==> 20210306_02, 3600.0s available
# 3600.0s filled by priority=0.0 objects
# ...

# %%
np.asarray(['early' in x for x in mastercat['object']]).any()
# Out:
# True

# %%
mastercat.loc[is_queued.is_queued].to_csv('../pointings/S2021A_predicted.csv')

# %%
obsobj = np.random.choice(mastercat.index,30)

# %%
is_queued = pd.DataFrame ( index=mastercat.index, columns=['is_queued'], dtype=bool)
is_queued.loc[obsobj,'is_queued'] = True

# %%
mastercat.loc[np.in1d(mastercat['object'], obsobj)]
# Out:
#                                  comment filter  seqtot  seqnum   seqid  \
# object
# GAMA_J143426.99-005528.78_N708        --   N708     512      24  S2021A
# GAMA_J142424.75-004828.74_N708        --   N708     512      25  S2021A
# GAMA_J142756.48-005642.92_N708        --   N708     512      28  S2021A
# GAMA_J140547.82-005527.10_N708        --   N708     512      38  S2021A
# GAMA_J115947.39-011059.87_N708        --   N708     512      72  S2021A
# GAMA_J114848.94+014728.28_N708        --   N708     512      89  S2021A
# GAMA_J111535.80+002731.37_N708        --   N708     512     133  S2021A
# GAMA_J111907.11+001631.72_N708        --   N708     512     136  S2021A
# GAMA_J111156.69-005841.16_N708        --   N708     512     137  S2021A
# GAMA_J105359.75+003130.70_N708        --   N708     512     149  S2021A
# GAMA_J121604.45+001858.91_N708        --   N708     512     186  S2021A
# GAMA_J125510.83+001821.02_N708        --   N708     512     212  S2021A
# ...
